# %% [markdown]
# # Дополнительное задание 8
# # Выполинли: Ибраев Дамир Беркутбаевич

# %% [markdown]
# ## Задание 1

# %% [markdown]
# На данном этапе подключаются необходимые библиотеки для обработки данных, построения моделей машинного обучения и оценки их качества.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import Lasso, Ridge, SGDRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_csv("Вариант2_1.csv", sep=';')
df.head()
# Out:
#        Weight,Height
# 0  126.7983,69.00102
# 1  131.9365,67.75162
# 2    135.9003,67.085
# 3   151.5006,69.0139
# 4  143.9136,66.13638

# %% [markdown]
# Первичный анализ данных: размер, типы и пропуски.

# %%
print(df.shape)
print(df.dtypes)
print(df.isna().sum())
# Out:
# (1000, 1)
# Weight,Height    object
# dtype: object
# Weight,Height    0
# dtype: int64

# %% [markdown]
# Все признаки являются числовыми, поэтому дополнительное кодирование не требуется.

# %% [markdown]
# Выделяем признаки и целевую переменную.

# %%
X = df.drop(columns=["y"])
y = df["y"]
